# %%
from cuppa1_cc import cc
from stackmachine_interp import interp
#1
x = \
'''
x = 1;
put x;
'''
print(x)
y = cc(x)
print(y)
print(interp(y))
#2
x = \
'''
get x;
x = x + 1;
put x;
'''
print(x)
y = cc(x)
print(y)
print(interp(y))
#3
x = \
'''
get x;
if (x)
put 1;
else
put 0;

'''
print(x)
y = cc(x)
print(y)
print(interp(y))
#4
x = \
'''
get x;
while (1 <= x)
{
put x;
x = x - 1;
}
'''
print(x)
y = cc(x)
print(y)
print(interp(y))
# Out:
# x = 1;
# put x;
#
# 	push 1 ;
# 	store x ;
# 	push x ;
# 	print ;
#
# > 1
# None
#
# get x;
# x = x + 1;
# put x;
#
# 	ask ;
# 	store x ;
# 	push x ;
# 	push 1 ;
# 	add ;
# 	store x ;
# 	push x ;
# 	print ;
#
# 5
# > 6
# None
#
# get x;
# if (x)
# put 1;
# else
# put 0;
#
#
# 	ask ;
# 	store x ;
# 	push x ;
# 	push 0 ;
# 	equ ;
# 	jumpT L0 ;
# 	push 1 ;
# 	print ;
# 	jump L1 ;
# L0:
# 	push 0 ;
# 	print ;
# L1:
# 	noop ;
#
# 5
# > 1
# None
#
# get x;
# while (1 <= x)
# {
# put x;
# x = x - 1;
# }
#
# 	ask ;
# 	store x ;
# L2:
# 	push 1 ;
# 	push x ;
# 	leq ;
# 	jumpF L3 ;
# 	push x ;
# 	print ;
# 	push x ;
# 	push 1 ;
# 	sub ;
# 	store x ;
# 	jump L2 ;
# L3:
# 	noop ;
#
# 5
# > 5
# > 4
# > 3
# > 2
# > 1
# None
