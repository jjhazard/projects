# %%
import pandas as pd
import numpy as np
from Dcopy import DecisionTree, Node

D = pd.read_csv('xTrain.csv')
E = pd.read_csv('yTrain.csv')
D["y"] = E.values
E = D[:100]
DT = DecisionTree(D)
# Out:
# X1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8b0d99b930e0> in <module>
#       7 D["y"] = E.values
#       8 E = D[:100]
# ----> 9 DT = DecisionTree(D)
#
# ~\Python\CSC461\Dcopy.py in __init__(self, D)
#      96     #initialize empty tree
#      97     def __init__(self, D):
# ---> 98         attributes =  list(D.columns.values)
#      99         self.head = self.GrowTree(0,D,attributes)
#     100
#
# ~\Python\CSC461\Dcopy.py in GrowTree(self, height, D, attributes)
#     124             return Node(data=self.majority(D),name="Leaf")
#     125
# --> 126         #choose column and value to split data on
#     127         gain,colname,split,D1,D2 = choose_attr(D, attributes, 'y')
#     128         hold = Node(data=split, name=colname)
#
# ~\Python\CSC461\Dcopy.py in choose_attr(df, attributes, predict_attr)
# ...
